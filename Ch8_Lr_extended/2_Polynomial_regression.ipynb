# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# %%
X = np.arange(6).reshape(3, 2)

# %%
X
# Out:
# array([[0, 1],
#        [2, 3],
#        [4, 5]])

# %%
poly = PolynomialFeatures(2)
poly.fit_transform(X)
# 처음부터 상수항, x1, x2, x1^2, x1*x2, x2^2
# Out:
# array([[ 1.,  0.,  1.,  0.,  0.,  1.],
#        [ 1.,  2.,  3.,  4.,  6.,  9.],
#        [ 1.,  4.,  5., 16., 20., 25.]])

# %%
poly = PolynomialFeatures(interaction_only=True)
poly.fit_transform(X)
# 제곱항 제외.
# Out:
# array([[ 1.,  0.,  1.,  0.],
#        [ 1.,  2.,  3.,  6.],
#        [ 1.,  4.,  5., 20.]])

# %%
import matplotlib.pyplot as plt

# %%
def f(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1
    return (x,y)

def sample(size):
    x = np.linspace(0, 5, size)
    y = x * np.sin(x ** 2) + 1 + np.random.randn(x.size)*0.5
    return (x,y)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
X, y = sample(1000)
plt.scatter(X, y, s=3, c="black")
plt.show()

# %%
#이런 곡선형태의 데이터분포를 적합시키자

# %%
X.shape, y.shape
# 각각 1 dim 인데 2 dimension으로 바꿔줘야 함.
# Out:
# ((1000,), (1000,))

# %%
X = X.reshape(-1, 1)
y = y.reshape(-1, 1)

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X).flatten())
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_features = PolynomialFeatures(degree=16)
X_poly = poly_features.fit_transform(X)
X_poly[:10]
# Out:
# array([[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00, 0.00000000e+00,
#         0.00000000e+00],
#        [1.00000000e+00, 5.00500501e-03, 2.50500751e-05, 1.25375751e-07,
#         6.27506263e-10, 3.14067198e-12, 1.57190790e-14, 7.86740691e-17,
#         3.93764110e-19, 1.97079134e-21, 9.86382051e-24, 4.93684710e-26,
#         2.47089445e-28, 1.23668391e-30, 6.18960915e-33, 3.09790248e-35,
#         1.55050174e-37],
#        [1.00000000e+00, 1.00100100e-02, 1.00200300e-04, 1.00300601e-06,
#         1.00401002e-08, 1.00501504e-10, 1.00602106e-12, 1.00702808e-14,
#         1.00803612e-16, 1.00904517e-18, 1.01005522e-20, 1.01106629e-22,
#         1.01207837e-24, 1.01309146e-26, 1.01410556e-28, 1.01512068e-30,
#         1.01613682e-32],
#        [1.00000000e+00, 1.50150150e-02, 2.25450676e-04, 3.38514528e-06,
#         5.08280073e-08, 7.63183292e-10, 1.14592086e-11, 1.72060189e-13,
#         2.58348632e-15, 3.87910859e-17, 5.82448738e-19, 8.74547654e-21,
#         1.31313462e-22, 1.97167360e-24, 2.96047087e-26, 4.44515145e-28,
#         6.67440158e-30],
#        [1.00000000e+00, 2.00200200e-02, 4.00801202e-04, 8.02404808e-06,
#         1.60641603e-07, 3.21604811e-09, 6.43853476e-11, 1.28899595e-12,
#         2.58057247e-14, 5.16631125e-16, 1.03429655e-17, 2.07066376e-19,
#         4.14547298e-21, 8.29924521e-23, 1.66151055e-24, 3.32634745e-26,
#         6.65935426e-28],
#        [1.00000000e+00, 2.50250250e-02, 6.26251878e-04, 1.56719689e-05,
#         3.92191414e-07, 9.81459995e-09, 2.45610609e-10, 6.14641165e-12,
#         1.53814105e-13, 3.84920183e-15, 9.63263722e-17, 2.41056988e-18,
#         6.03245715e-20, 1.50962391e-21, 3.77783761e-23, 9.45404808e-25,
#         2.36587790e-26],
#        [1.00000000e+00, 3.00300300e-02, 9.01802704e-04, 2.70811623e-05,
#         8.13248116e-07, 2.44218654e-08, 7.33389350e-10, 2.20237042e-11,
#         6.61372499e-13, 1.98610360e-14, 5.96427507e-16, 1.79107360e-17,
#         5.37859939e-19, 1.61519501e-20, 4.85043547e-22, 1.45658723e-23,
#         4.37413582e-25],
#        [1.00000000e+00, 3.50350350e-02, 1.22745368e-03, 4.30038827e-05,
#         1.50664254e-06, 5.27852740e-08, 1.84933393e-09, 6.47914789e-11,
#         2.26997173e-12, 7.95285392e-14, 2.78628516e-15, 9.76175981e-17,
#         3.42003597e-18, 1.19821080e-19, 4.19793573e-21, 1.47074826e-22,
#         5.15277167e-24],
#        [1.00000000e+00, 4.00400400e-02, 1.60320481e-03, 6.41923846e-05,
#         2.57026565e-06, 1.02913540e-07, 4.12066225e-09, 1.64991481e-10,
#         6.60626552e-12, 2.64515136e-13, 1.05911966e-14, 4.24071937e-16,
#         1.69798573e-17, 6.79874168e-19, 2.72221889e-20, 1.08997753e-21,
#         4.36427441e-23],
#        [1.00000000e+00, 4.50450450e-02, 2.02905608e-03, 9.13989227e-05,
#         4.11706859e-06, 1.85453540e-07, 8.35376306e-09, 3.76295634e-10,
#         1.69502538e-11, 7.63524944e-13, 3.43930155e-14, 1.54923493e-15,
#         6.97853573e-17, 3.14348456e-18, 1.41598404e-19, 6.37830648e-21,
#         2.87311103e-22]])

# %%
lr = LinearRegression()
lr.fit(X_poly,y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
f_x, f_y = f(1000)
plt.plot(f_x, f_y)
plt.scatter(X.flatten(), y.flatten(), s=3, c="black")
plt.plot(X.flatten(), lr.predict(X_poly).flatten())
plt.show()

# %%
def rmse(predictions, targets):
    return np.sqrt(((predictions - targets) ** 2).mean())

# %%
poly_range = list(range(10, 50))
rmse_lr_list = []
rmse_lasso_list = []
rmse_ridge_list = []

from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge

for poly_value in poly_range:
    poly_features = PolynomialFeatures(degree=poly_value)
    X_poly = poly_features.fit_transform(X)
    lr = LinearRegression()
    lr.fit(X_poly,y)
    
    rmse_lr_list.append(rmse(lr.predict(X_poly), y))

    lasso = Lasso()
    lasso.fit(X_poly,y)
    rmse_lasso_list.append(rmse(lasso.predict(X_poly), y))
    
    ridge = Ridge()
    ridge.fit(X_poly,y)
    rmse_ridge_list.append(rmse(ridge.predict(X_poly), y))
# Out:
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2048.72820994557, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2041.7494978356153, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=9.00523e-18): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2035.5839238535573, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=3.85959e-19): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2028.7162778079846, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=1.64691e-20): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2022.4901186370137, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\ridge.py:147: LinAlgWarning: Ill-conditioned matrix (rcond=6.99999e-22): result may not be accurate.
#   overwrite_a=True).T
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2017.4789107556207, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2013.8535027915873, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2011.5506488142885, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.3559290400551, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.0079012950434, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.1738416523638, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.587039302807, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.9574402726462, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2011.0883727879668, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.8157463356886, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2010.0044691903768, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2008.520397150388, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2006.2649584650817, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2003.1546588448896, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1999.1261455846304, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1994.1157754604315, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1988.1148923115932, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1981.122825762435, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1973.176724105558, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1966.7902517156929, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1960.1679842378035, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1953.2740378476565, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1946.153655207479, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1938.7428292522472, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1931.0872092530474, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1923.2441922179635, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1915.2953385538726, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1907.3309423566195, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1899.4257619955285, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1891.6587103104584, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1884.0932847443357, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1876.796855198599, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1869.8191263960503, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1863.1881891416404, tolerance: 0.4483525376571597
#   positive)
# C:\Users\cross\Anaconda3\lib\site-packages\sklearn\linear_model\coordinate_descent.py:475: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1856.9510153964331, tolerance: 0.4483525376571597
#   positive)

# %%
import pandas as pd
from pandas import DataFrame
data = {"poly_range":poly_range, "lr_rmse":rmse_lr_list, 
        "lasso_rmse":rmse_lasso_list,"ridge_rmse":rmse_ridge_list}
df = DataFrame(data).set_index("poly_range")
df
# Out:
#              lr_rmse  lasso_rmse  ridge_rmse
# poly_range
# 10          1.904578    2.205553    1.930204
# 11          1.894195    2.213844    1.907617
# 12          1.648523    2.218794    1.905063
# 13          1.380234    2.221789    1.876344
# 14          1.368227    2.223599    1.706390
# 15          0.932100    2.224645    1.503317
# 16          0.716546    2.225144    1.511192
# 17          0.686025    2.225232    1.322866
# 18          0.713926    2.225016    0.910355
# 19          0.665338    2.224608    0.774331
# 20          0.659445    2.224126    0.767600
# 21          0.637952    2.223705    0.622384
# 22          0.540751    2.223475    0.526046
# 23          0.537099    2.223568    0.527022
# 24          0.606849    2.224093    0.558169
# 25          0.700089    2.225134    0.679916
# 26          0.796336    2.226733    0.669329
# 27          0.960444    2.228904    0.677323
# 28          1.087931    2.231624    0.972748
# 29          1.149220    2.234847    0.995044
# 30          1.144035    2.238503    1.041604
# 31          1.245641    2.242520    1.064903
# 32          1.301343    2.246818    1.710247
# 33          1.335620    2.251318    1.149100
# 34          1.343513    2.257483    1.072577
# 35          1.328961    2.263738    3.066350
# 36          1.301030    2.269649    3.019462
# 37          1.270790    2.275282    1.244596
# 38          1.250397    2.280639    1.481837
# 39          1.241436    2.285702    1.286425
# 40          1.250878    2.290469    1.314149
# 41          1.287624    2.294942    1.271271
# 42          1.510560    2.299129    1.378656
# 43          1.499032    2.303032    1.342635
# 44          1.544522    2.306661    1.495745
# 45          1.470648    2.310020    1.464577
# 46          1.497750    2.313115    1.468039
# 47          1.488744    2.315953    1.494327
# 48          1.525308    2.318537    1.611896
# 49          1.453548    2.320874    1.500618

# %%
plt.plot(poly_range, df["ridge_rmse"], label="ridge")
plt.plot(poly_range, df["lr_rmse"], label="lr")
plt.plot(poly_range, df["lasso_rmse"], label="lasso")
plt.legend()
plt.show()

# %%
df.min()
# Out:
# lr_rmse       0.537099
# lasso_rmse    2.205553
# ridge_rmse    0.526046
# dtype: float64

# %%
df = pd.read_csv("yield.csv", sep="\t")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-42-c80e0dbefe6c> in <module>
# ----> 1 df = pd.read_csv("yield.csv", sep="\t")
#       2 df.head()
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     683         )
#     684
# --> 685         return _read(filepath_or_buffer, kwds)
#     686
#     687     parser_f.__name__ = name
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(fp_or_buf, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options["has_index_names"] = kwds["has_index_names"]
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1133     def _make_engine(self, engine="c"):
#    1134         if engine == "c":
# -> 1135             self._engine = CParserWrapper(self.f, **self.options)
#    1136         else:
#    1137             if engine == "python":
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1915         kwds["usecols"] = self.usecols
#    1916
# -> 1917         self._reader = parsers.TextReader(src, **kwds)
#    1918         self.unnamed_cols = self._reader.unnamed_cols
#    1919
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'yield.csv' does not exist: b'yield.csv'
